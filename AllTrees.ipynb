# %%
import os
import re

files = os.popen('find /Users/elenajudd/documents/ISGPROJECT/FINALGENELISTS -type f -name "*tree.txt"').read()
filelist = files.split()

# %%
for file in filelist:
    with open(file) as f:
        for line in f:
            line = line.strip('(')
            line = line.strip(')')
            print(line)
# Out:
# DrillMonkey,(SootyMangabey,BlackMangabey)), Baboon), ((RhesusMacaque,CrabEeatingMacaque), PigTailedMacaque)), GreenMonkey),(Colobus, GoldenSnubNosedMonkey)),
#
# Human, (Chimp, Bonobo)), Gorilla), Gibbon),
#
# ;
#
#
#
#
#
# Bonobo_CHUK_XM_003825463, Chimp_CHUK_XM_009458890), Human_CHUK_NM_001278),
#
#
#
# Rhesus_CHUK_XM_001107171, Crab-eatingMacaque_CHUK_XM_005566180),Pig-tailedMacaque_CHUK_XM_011735669), (OliveBaboon_CHUK_XM_003904116, (Drill_CHUK_XM_011977386, SootyMangabey_CHUK_XM_012051472))), GreenMonkey_CHUK_XM_007963830), (Colobus_CHUK_XM_011935557, GoldenSnub-nosedMonkey_CHUK_XM_010356085)),
#
#
#
# OwlMonkey_CHUK_XM_012439531, SquirrelMonkey_CHUK_XM_010333190)
#
#
#
#
#
#
#
# ;
#
#
#
#
# Bonobo_CISH_XM_003818802, Chimp_CISH_XM_003309810), Human_CISH_NM_145071), Gorilla_CISH_XM_004034215), Orangutan_CISH_XM_002813706), White-cheekedGibbon_CISH_XM_003257120),
#
#
#
# ...

# %%
from collections import Counter
import re

# %%
document_text = open('/Users/elenajudd/documents/AllTrees.txt')
text_string = document_text.read().lower()

# %%
match_pattern = re.search(r'\b[a-z]{3,15}\b', text_string)
print match_pattern
# Out:
# None

# %%
for word in match_pattern:
    count = frequency.get(word,0)
    frequency[word] = count + 1
# Out:
#   File "<ipython-input-66-7e29b81743ca>", line 1
#     for word in text_string
#                            ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-5906062571f5> in <module>()
# ----> 1 for word in match_pattern:
#       2     count = frequency.get(word,0)
#       3     frequency[word] = count + 1
#
# TypeError: 'NoneType' object is not iterable
